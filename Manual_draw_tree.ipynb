# %%
from anytree import Node, RenderTree, AsciiStyle, ContRoundStyle, ContStyle, DoubleStyle, search
from anytree.exporter import DotExporter
# graphviz needs to be installed for the next line!
from IPython.display import Image

# %%
ADJ = None
ADP = None
AUX = None
BEMsa = None
BedZa = None
CCONJ = None
NOUN = None
PUNCT = None
SAmila = None
VERB = None
acl = None
bakarI = None
case = None
cc = None
comma0 = None
compound = None
conj = None
cop = None
hEM = None
hadZappA = None
haddiyAz = None
haddiyoM = None
jAnavaroM = None
kI = None
maveSiyoM = None
meM = None
milI = None
nmod = None
node0 = None
node1 = None
node10 = None
node11 = None
node12 = None
node13 = None
node14 = None
node15 = None
node16 = None
node17 = None
node18 = None
node19 = None
node2 = None
node20 = None
node21 = None
node22 = None
node23 = None
node3 = None
node4 = None
node5 = None
node6 = None
node7 = None
node8 = None
node9 = None
nsubj = None
obl = None
pipe = None
punct = None
root = None
sUara = None
sWaloM = None
se = None
waWA = None

# %%
node1 = Node("hadZappA", parent=node2, PID=node1 , WORD=hadZappA, POS=NOUN, RELATION=compound)
node2 = Node("sWaloM", parent=node4, PID=node2 , WORD=sWaloM, POS=NOUN, RELATION=obl)
node3 = Node("se", parent=node2, PID=node3 , WORD=se, POS=ADP, RELATION=case)
node4 = Node("milI", parent=node5, PID=node4 , WORD=milI, POS=VERB, RELATION=acl)
node5 = Node("jAnavaroM", parent=node7, PID=node5 , WORD=jAnavaroM, POS=NOUN, RELATION=nmod)
node6 = Node("kI", parent=node5, PID=node6 , WORD=kI, POS=ADP, RELATION=case)
node7 = Node("haddiyoM", parent=node21, PID=node7 , WORD=haddiyoM, POS=NOUN, RELATION=nmod)
node8 = Node("meM", parent=node7, PID=node8 , WORD=meM, POS=ADP, RELATION=case)
node9 = Node("maveSiyoM", parent=node20, PID=node9 , WORD=maveSiyoM, POS=NOUN, RELATION=nmod)
node10 = Node("comma0", parent=node11, PID=node10 , WORD=comma0, POS=PUNCT, RELATION=punct)
node11 = Node("BedZa", parent=node9, PID=node11 , WORD=BedZa, POS=NOUN, RELATION=conj)
node12 = Node("comma0", parent=node13, PID=node12 , WORD=comma0, POS=PUNCT, RELATION=punct)
node13 = Node("bakarI", parent=node9, PID=node13 , WORD=bakarI, POS=NOUN, RELATION=conj)
node14 = Node("comma0", parent=node15, PID=node14 , WORD=comma0, POS=PUNCT, RELATION=punct)
node15 = Node("BEMsa", parent=node9, PID=node15 , WORD=BEMsa, POS=NOUN, RELATION=conj)
node16 = Node("comma0", parent=node18, PID=node16 , WORD=comma0, POS=PUNCT, RELATION=punct)
node17 = Node("waWA", parent=node18, PID=node17 , WORD=waWA, POS=CCONJ, RELATION=cc)
node18 = Node("sUara", parent=node9, PID=node18 , WORD=sUara, POS=NOUN, RELATION=conj)
node19 = Node("kI", parent=node18, PID=node19 , WORD=kI, POS=ADP, RELATION=case)
node20 = Node("haddiyAz", parent=node21, PID=node20 , WORD=haddiyAz, POS=NOUN, RELATION=nsubj)
node21 = Node("SAmila", parent=node0, PID=node21 , WORD=SAmila, POS=ADJ, RELATION=root)
node22 = Node("hEM", parent=node21, PID=node22 , WORD=hEM, POS=AUX, RELATION=cop)
node23 = Node("pipe", parent=node21, PID=node23 , WORD=pipe, POS=PUNCT, RELATION=punct)

# %%
print(type(node9))

print(RenderTree(node9, style=ContRoundStyle()))

# Render graph tree
DotExporter(node9).to_picture("node9.png")
Image(filename='node9.png')
# Out:
# <class 'anytree.node.node.Node'>
# Node('/maveSiyoM', PID=None, POS=None, RELATION=None, WORD=None)
# ├── Node('/maveSiyoM/BedZa', PID=None, POS=None, RELATION=None, WORD=None)
# ├── Node('/maveSiyoM/bakarI', PID=None, POS=None, RELATION=None, WORD=None)
# ├── Node('/maveSiyoM/BEMsa', PID=None, POS=None, RELATION=None, WORD=None)
# ╰── Node('/maveSiyoM/sUara', PID=None, POS=None, RELATION=None, WORD=None)
#     ╰── Node('/maveSiyoM/sUara/kI', PID=None, POS=None, RELATION=None, WORD=None)

# %% [markdown]
# # All

# %%
# %%nbtutor -r -f

from anytree import Node, RenderTree, AsciiStyle, ContRoundStyle, ContStyle, DoubleStyle, search
from anytree.exporter import DotExporter
# graphviz needs to be installed for the next line!
from IPython.display import Image

node0=Node('root')
node21=Node('SAmila' , parent=node0)
node20=Node('haddiyAz' , parent=node21)
node9=Node('maveSiyoM' , parent=node20)
node22=Node('hEM' , parent=node21)
node23=Node('pipe' , parent=node21)
node15=Node('BEMsa' , parent=node9)
node11=Node('BedZa' , parent=node9)
node18=Node('sUara' , parent=node9)
node13=Node('bakarI' , parent=node9)
node19=Node('kI' , parent=node18)
node16=Node('comma0' , parent=node18)
node17=Node('waWA' , parent=node18)
node10=Node('comma0' , parent=node11)
node14=Node('comma0' , parent=node15)
node12=Node('comma0' , parent=node13)
node7=Node('haddiyoM' , parent=node21)
node5=Node('jAnavaroM' , parent=node7)
node6=Node('kI' , parent=node5)
node8=Node('meM' , parent=node7)
node4=Node('milI' , parent=node5)
node2=Node('sWaloM' , parent=node4)
node3=Node('se' , parent=node2)
node1=Node('hadZappA' , parent=node2)
           

print(RenderTree(node0, style=ContRoundStyle())) # Render Tree

DotExporter(node0).to_picture("node0.png") # Render image tree

Image(filename='node0.png') # Display render image in ipyton
# Out:
# Node('/root')
# ╰── Node('/root/SAmila')
#     ├── Node('/root/SAmila/haddiyAz')
#     │   ╰── Node('/root/SAmila/haddiyAz/maveSiyoM')
#     │       ├── Node('/root/SAmila/haddiyAz/maveSiyoM/BEMsa')
#     │       │   ╰── Node('/root/SAmila/haddiyAz/maveSiyoM/BEMsa/comma0')
#     │       ├── Node('/root/SAmila/haddiyAz/maveSiyoM/BedZa')
#     │       │   ╰── Node('/root/SAmila/haddiyAz/maveSiyoM/BedZa/comma0')
#     │       ├── Node('/root/SAmila/haddiyAz/maveSiyoM/sUara')
#     │       │   ├── Node('/root/SAmila/haddiyAz/maveSiyoM/sUara/kI')
#     │       │   ├── Node('/root/SAmila/haddiyAz/maveSiyoM/sUara/comma0')
#     │       │   ╰── Node('/root/SAmila/haddiyAz/maveSiyoM/sUara/waWA')
#     │       ╰── Node('/root/SAmila/haddiyAz/maveSiyoM/bakarI')
#     │           ╰── Node('/root/SAmila/haddiyAz/maveSiyoM/bakarI/comma0')
#     ├── Node('/root/SAmila/hEM')
#     ├── Node('/root/SAmila/pipe')
#     ╰── Node('/root/SAmila/haddiyoM')
# ...
